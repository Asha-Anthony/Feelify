# %%
# !pip install diffusers
# !pip install transformers
# !pip install accelerate
# !pip install pydub
# Out:
# Collecting diffusers
#   Downloading diffusers-0.19.3-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: numpy in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (1.23.5)
# Collecting huggingface-hub>=0.13.2
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      -------------------------------------- 268.8/268.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (2.28.1)
# Requirement already satisfied: importlib-metadata in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (4.11.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (2022.7.9)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.1-cp310-cp310-win_amd64.whl (263 kB)
#      -------------------------------------- 263.7/263.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from diffusers) (3.9.0)
# Requirement already satisfied: fsspec in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (2022.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (22.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (6.0)
# Requirement already satisfied: zipp>=0.5 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from importlib-metadata->diffusers) (3.11.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->diffusers) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->diffusers) (2023.7.22)
# Requirement already satisfied: colorama in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.13.2->diffusers) (0.4.6)
# Installing collected packages: safetensors, huggingface-hub, diffusers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
# Successfully installed diffusers-0.19.3 huggingface-hub-0.16.4 safetensors-0.3.1
# Requirement already satisfied: transformers in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (4.24.0)
# Requirement already satisfied: numpy>=1.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: requests in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: filelock in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (0.16.4)
# Requirement already satisfied: tqdm>=4.27 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: packaging>=20.0 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: pyyaml>=5.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: fsspec in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (2022.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from requests->transformers) (2023.7.22)
# Collecting accelerate
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      -------------------------------------- 244.2/244.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from accelerate) (1.12.1)
# Requirement already satisfied: packaging>=20.0 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from accelerate) (22.0)
# Requirement already satisfied: psutil in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: numpy>=1.17 in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from accelerate) (1.23.5)
# Requirement already satisfied: typing_extensions in d:\douglas\final semester\machine learning\anaconda\lib\site-packages (from torch>=1.10.0->accelerate) (4.4.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.21.0
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import torch
from diffusers import StableDiffusionPipeline

import numpy as np
from PIL import Image
import pydub
from scipy.io import wavfile
import torch
import torchaudio
import io
import typing as T
from pydub import AudioSegment
from IPython.display import Audio, display
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torch
# ----> 2 from diffusers import StableDiffusionPipeline
#       4 import numpy as np
#       5 from PIL import Image
#
# File D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\diffusers\__init__.py:38
#      36     from .utils.dummy_pt_objects import *  # noqa F403
#      37 else:
# ---> 38     from .models import (
#      39         AsymmetricAutoencoderKL,
#      40         AutoencoderKL,
#      41         ControlNetModel,
#      42         ModelMixin,
#      43         MultiAdapter,
#      44         PriorTransformer,
#      45         T2IAdapter,
#      46         T5FilmDecoder,
#      47         Transformer2DModel,
#      48         UNet1DModel,
#      49         UNet2DConditionModel,
#      50         UNet2DModel,
#      51         UNet3DConditionModel,
#      52         VQModel,
#      53     )
#      54     from .optimization import (
#      55         get_constant_schedule,
#      56         get_constant_schedule_with_warmup,
#    (...)
#      61         get_scheduler,
#      62     )
#      63     from .pipelines import (
#      64         AudioPipelineOutput,
#      65         AutoPipelineForImage2Image,
#    (...)
#      80         ScoreSdeVePipeline,
#      81     )
#
# File D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\diffusers\models\__init__.py:20
#      18 if is_torch_available():
#      19     from .adapter import MultiAdapter, T2IAdapter
# ---> 20     from .autoencoder_asym_kl import AsymmetricAutoencoderKL
#      21     from .autoencoder_kl import AutoencoderKL
#      22     from .controlnet import ControlNetModel
#
# File D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\diffusers\models\autoencoder_asym_kl.py:21
#      19 from ..configuration_utils import ConfigMixin, register_to_config
#      20 from ..utils import apply_forward_hook
# ---> 21 from .autoencoder_kl import AutoencoderKLOutput
#      22 from .modeling_utils import ModelMixin
#      23 from .vae import DecoderOutput, DiagonalGaussianDistribution, Encoder, MaskConditionDecoder
#
# File D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\diffusers\models\autoencoder_kl.py:21
#      18 import torch.nn as nn
#      20 from ..configuration_utils import ConfigMixin, register_to_config
# ---> 21 from ..loaders import FromOriginalVAEMixin
#      22 from ..utils import BaseOutput, apply_forward_hook
#      23 from .attention_processor import AttentionProcessor, AttnProcessor
#
# File D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\diffusers\loaders.py:47
#      44     import safetensors
#      46 if is_transformers_available():
# ---> 47     from transformers import CLIPTextModel, CLIPTextModelWithProjection, PreTrainedModel, PreTrainedTokenizer
#      49 if is_accelerate_available():
#      50     from accelerate import init_empty_weights
#
# ImportError: cannot import name 'CLIPTextModelWithProjection' from 'transformers' (D:\Douglas\Final semester\Machine Learning\anaconda\lib\site-packages\transformers\__init__.py)

# %%
model_id2 = "riffusion/riffusion-model-v1"
pipe2 = StableDiffusionPipeline.from_pretrained(model_id2, torch_dtype=torch.float16)
pipe2 = pipe2.to("cuda")

# %%
#@title functions
def get_music(prompt, musicAI_indx, duration):
    mp3file_name = "audio.mp3"
    wavfile_name = "audio.wav"
    if musicAI_indx == 0:
        if duration == 5:
            width_duration=512
        else :
            width_duration = 512 + ((int(duration)-5) * 128)
        spec = pipe2(prompt, height=512, width=width_duration).images[0]
        print(spec)
        wav = wav_bytes_from_spectrogram_image(spec)
        with open(wavfile_name, "wb") as f:
            f.write(wav[0].getbuffer())


        #Convert to mp3, for video merging function
        wavfile = AudioSegment.from_wav(wavfile_name)
        wavfile.export(mp3file_name, format="mp3")
        return spec, mp3file_name
def wav_bytes_from_spectrogram_image(image: Image.Image) -> T.Tuple[io.BytesIO, float]:
    """
    Reconstruct a WAV audio clip from a spectrogram image. Also returns the duration in seconds.
    """

    max_volume = 50
    power_for_image = 0.25
    Sxx = spectrogram_from_image(image, max_volume=max_volume, power_for_image=power_for_image)

    sample_rate = 44100  # [Hz]
    clip_duration_ms = 5000  # [ms]

    bins_per_image = 512
    n_mels = 512

    # FFT parameters
    window_duration_ms = 100  # [ms]
    padded_duration_ms = 400  # [ms]
    step_size_ms = 10  # [ms]

    # Derived parameters
    num_samples = int(image.width / float(bins_per_image) * clip_duration_ms) * sample_rate
    n_fft = int(padded_duration_ms / 1000.0 * sample_rate)
    hop_length = int(step_size_ms / 1000.0 * sample_rate)
    win_length = int(window_duration_ms / 1000.0 * sample_rate)

    samples = waveform_from_spectrogram(
        Sxx=Sxx,
        n_fft=n_fft,
        hop_length=hop_length,
        win_length=win_length,
        num_samples=num_samples,
        sample_rate=sample_rate,
        mel_scale=True,
        n_mels=n_mels,
        max_mel_iters=200,
        num_griffin_lim_iters=32,
    )

    wav_bytes = io.BytesIO()
    wavfile.write(wav_bytes, sample_rate, samples.astype(np.int16))
    wav_bytes.seek(0)

    duration_s = float(len(samples)) / sample_rate

    return wav_bytes, duration_s


def spectrogram_from_image(
    image: Image.Image, max_volume: float = 50, power_for_image: float = 0.25
) -> np.ndarray:
    """
    Compute a spectrogram magnitude array from a spectrogram image.
    TODO(hayk): Add image_from_spectrogram and call this out as the reverse.
    """
    # Convert to a numpy array of floats
    data = np.array(image).astype(np.float32)

    # Flip Y take a single channel
    data = data[::-1, :, 0]

    # Invert
    data = 255 - data

    # Rescale to max volume
    data = data * max_volume / 255

    # Reverse the power curve
    data = np.power(data, 1 / power_for_image)

    return data

def waveform_from_spectrogram(
    Sxx: np.ndarray,
    n_fft: int,
    hop_length: int,
    win_length: int,
    num_samples: int,
    sample_rate: int,
    mel_scale: bool = True,
    n_mels: int = 512,
    max_mel_iters: int = 200,
    num_griffin_lim_iters: int = 32,
    device: str = "cuda:0",
) -> np.ndarray:
    """
    Reconstruct a waveform from a spectrogram.
    This is an approximate inverse of spectrogram_from_waveform, using the Griffin-Lim algorithm
    to approximate the phase.
    """
    Sxx_torch = torch.from_numpy(Sxx).to(device)

    # TODO(hayk): Make this a class that caches the two things

    if mel_scale:
        mel_inv_scaler = torchaudio.transforms.InverseMelScale(
            n_mels=n_mels,
            sample_rate=sample_rate,
            f_min=0,
            f_max=10000,
            n_stft=n_fft // 2 + 1,
            norm=None,
            mel_scale="htk",
            max_iter=max_mel_iters,
        ).to(device)

        Sxx_torch = mel_inv_scaler(Sxx_torch)

    griffin_lim = torchaudio.transforms.GriffinLim(
        n_fft=n_fft,
        win_length=win_length,
        hop_length=hop_length,
        power=1.0,
        n_iter=num_griffin_lim_iters,
    ).to(device)

    waveform = griffin_lim(Sxx_torch).cpu().numpy()

    return waveform


def mp3_bytes_from_wav_bytes(wav_bytes: io.BytesIO) -> io.BytesIO:
    mp3_bytes = io.BytesIO()
    sound = pydub.AudioSegment.from_wav(wav_bytes)
    sound.export(mp3_bytes, format="mp3")
    mp3_bytes.seek(0)
    return mp3_bytes

# %%
get_music(prompt="jazz", musicAI_indx=0, duration=6)
display(Audio('audio.mp3', autoplay=True))

# %%
get_music(prompt="fight club", musicAI_indx=0, duration=5)
display(Audio('audio.mp3', autoplay=True))
